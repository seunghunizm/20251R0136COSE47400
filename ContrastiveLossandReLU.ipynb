# %%
# Build gallery-style JSON from annos (with category_id)
import os
import json
import numpy as np
import torch
from PIL import Image
import matplotlib.pyplot as plt
from torchvision import models, transforms
import faiss
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import random

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
random.seed(43)
torch.manual_seed(43)
np.random.seed(43)

class FashionRetrievalModel(nn.Module):
    def __init__(self, embedding_dim=512):
        super().__init__()
        self.backbone = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        num_ftrs = self.backbone.fc.in_features
        self.backbone.fc = nn.Identity()
        self.embedding = nn.Sequential(
            nn.Linear(num_ftrs, embedding_dim),
            nn.ReLU(),
            nn.BatchNorm1d(embedding_dim)
        )

    def forward(self, x):
        features = self.backbone(x)
        return F.normalize(self.embedding(features), p=2, dim=1)

# Triplet Dataset
class TripletFashionDataset(torch.utils.data.Dataset):
    def __init__(self, image_folder, annotation_path, annos_folder, transform):
        self.image_folder = image_folder
        self.annotation_path = annotation_path
        self.annos_folder = annos_folder
        self.transform = transform

        print(f"📂 Loading annotations from: {annotation_path}")
        with open(annotation_path) as f:
            self.data = json.load(f)

        self.category_to_images = {}
        for item in self.data:
            gallery_id = item.get("gallery_image_id")
            pair_id = item.get("pair_id")
            if gallery_id is not None and pair_id is not None:
                file_name = f"{gallery_id:06d}.jpg"
                full_path = os.path.join(image_folder, file_name)
                if os.path.isfile(full_path):
                    self.category_to_images.setdefault(pair_id, []).append(file_name)

        self.image_triplets = self._generate_triplets()
        print(f"✅ Triplets generated: {len(self.image_triplets)}")

    def _load_and_crop(self, filename):
        img_path = os.path.join(self.image_folder, filename)
        ann_path = os.path.join(self.annos_folder, filename.replace('.jpg', '.json'))
        img = Image.open(img_path).convert("RGB")
        if os.path.isfile(ann_path):
            with open(ann_path) as f:
                ann = json.load(f)
                if "bounding_box" in ann:
                    x, y, w, h = ann["bounding_box"]
                    img = img.crop((x, y, x + w, y + h))
        return img

    def _generate_triplets(self):
        triplets = []
        categories = list(self.category_to_images.keys())
        for cat in categories:
            imgs = self.category_to_images[cat]
            if len(imgs) < 2:
                continue
            for i in range(len(imgs) - 1):
                anchor = imgs[i]
                positive = imgs[i + 1]
                neg_cat = random.choice([c for c in categories if c != cat and len(self.category_to_images[c]) > 0])
                negative = self.category_to_images[neg_cat][0]
                triplets.append((anchor, positive, negative))
        return triplets

    def __len__(self):
        return len(self.image_triplets)

    def __getitem__(self, idx):
        a, p, n = self.image_triplets[idx]
        a_img = self._load_and_crop(a)
        p_img = self._load_and_crop(p)
        n_img = self._load_and_crop(n)
        if self.transform:
            a_img = self.transform(a_img)
            p_img = self.transform(p_img)
            n_img = self.transform(n_img)
        return a_img, p_img, n_img

#Contrastive Loss Function
class ContrastiveLoss(nn.Module):
    def __init__(self, margin=1.0):
        super().__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss = torch.mean(
            label * torch.pow(euclidean_distance, 2) +
            (1 - label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2)
        )
        return loss

# Training loop
def train(model, dataloader, optimizer, criterion, epochs=10):
    model.train()
    for epoch in range(epochs):
        total_loss = 0.0
        for i, (anchor, positive, negative) in enumerate(dataloader):
            anchor, positive, negative = anchor.to(DEVICE), positive.to(DEVICE), negative.to(DEVICE)
            a_embed = model(anchor)
            p_embed = model(positive)
            n_embed = model(negative)

            # Labels: 1 for positive pair, 0 for negative pair
            pos_labels = torch.ones(anchor.size(0)).to(DEVICE)
            neg_labels = torch.zeros(anchor.size(0)).to(DEVICE)

            loss_pos = criterion(a_embed, p_embed, pos_labels)
            loss_neg = criterion(a_embed, n_embed, neg_labels)
            loss = loss_pos + loss_neg

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if i % 10 == 0:
                print(f"Epoch {epoch+1} | Batch {i}/{len(dataloader)} | Loss: {loss.item():.4f}")

        avg_loss = total_loss / len(dataloader)
        print(f"✅ Epoch {epoch+1} complete | Avg Loss: {avg_loss:.4f}")

# %%
image_folder = "validation/validation/image"
annotation_path = "val_annotations/json_for_validation/val_gallery.json"
annos_folder = "validation/validation/annos"

train_dataset = TripletFashionDataset(image_folder, annotation_path, annos_folder, transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

model = FashionRetrievalModel().to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = ContrastiveLoss(margin=1.0)

train(model, train_loader, optimizer, criterion, epochs=10)
# Out:
# 📂 Loading annotations from: val_annotations/json_for_validation/val_gallery.json
# ✅ Triplets generated: 34682
# Epoch 1 | Batch 0/1084 | Loss: 0.9262
# Epoch 1 | Batch 10/1084 | Loss: 0.8210
# Epoch 1 | Batch 20/1084 | Loss: 0.7902
# Epoch 1 | Batch 30/1084 | Loss: 0.8192
# Epoch 1 | Batch 40/1084 | Loss: 0.7427
# Epoch 1 | Batch 50/1084 | Loss: 0.5757
# Epoch 1 | Batch 60/1084 | Loss: 0.5280
# Epoch 1 | Batch 70/1084 | Loss: 0.3716
# Epoch 1 | Batch 80/1084 | Loss: 0.2844
# Epoch 1 | Batch 90/1084 | Loss: 0.2459
# Epoch 1 | Batch 100/1084 | Loss: 0.3226
# Epoch 1 | Batch 110/1084 | Loss: 0.3481
# Epoch 1 | Batch 120/1084 | Loss: 0.6664
# Epoch 1 | Batch 130/1084 | Loss: 0.2744
# Epoch 1 | Batch 140/1084 | Loss: 0.2110
# Epoch 1 | Batch 150/1084 | Loss: 0.1941
# Epoch 1 | Batch 160/1084 | Loss: 0.2859
# Epoch 1 | Batch 170/1084 | Loss: 0.2846
# Epoch 1 | Batch 180/1084 | Loss: 0.2314
# Epoch 1 | Batch 190/1084 | Loss: 0.1220
# Epoch 1 | Batch 200/1084 | Loss: 0.2222
# Epoch 1 | Batch 210/1084 | Loss: 0.2704
# Epoch 1 | Batch 220/1084 | Loss: 0.1897
# Epoch 1 | Batch 230/1084 | Loss: 0.1717
# Epoch 1 | Batch 240/1084 | Loss: 0.2084
# Epoch 1 | Batch 250/1084 | Loss: 0.1356
# Epoch 1 | Batch 260/1084 | Loss: 0.1785
# Epoch 1 | Batch 270/1084 | Loss: 0.1729
# Epoch 1 | Batch 280/1084 | Loss: 0.1132
# Epoch 1 | Batch 290/1084 | Loss: 0.1934
# Epoch 6 | Batch 140/1084 | Loss: 0.0415
# Epoch 6 | Batch 150/1084 | Loss: 0.0171
# Epoch 6 | Batch 160/1084 | Loss: 0.0208
# Epoch 6 | Batch 170/1084 | Loss: 0.0479
# Epoch 6 | Batch 180/1084 | Loss: 0.0125
# Epoch 6 | Batch 190/1084 | Loss: 0.0708
# Epoch 6 | Batch 200/1084 | Loss: 0.0173
# Epoch 6 | Batch 210/1084 | Loss: 0.0524
# Epoch 6 | Batch 220/1084 | Loss: 0.0508
# Epoch 6 | Batch 230/1084 | Loss: 0.0234
# Epoch 6 | Batch 240/1084 | Loss: 0.0294
# Epoch 6 | Batch 250/1084 | Loss: 0.0783
# Epoch 6 | Batch 260/1084 | Loss: 0.0369
# Epoch 6 | Batch 270/1084 | Loss: 0.0329
# Epoch 6 | Batch 280/1084 | Loss: 0.0224
# Epoch 6 | Batch 290/1084 | Loss: 0.0176
# Epoch 6 | Batch 300/1084 | Loss: 0.0314
# Epoch 6 | Batch 310/1084 | Loss: 0.0305
# Epoch 6 | Batch 320/1084 | Loss: 0.0682
# Epoch 6 | Batch 330/1084 | Loss: 0.0346
# Epoch 6 | Batch 340/1084 | Loss: 0.0130
# Epoch 6 | Batch 350/1084 | Loss: 0.0241
# Epoch 6 | Batch 360/1084 | Loss: 0.0182
# Epoch 6 | Batch 370/1084 | Loss: 0.0246
# Epoch 6 | Batch 380/1084 | Loss: 0.0708
# Epoch 6 | Batch 390/1084 | Loss: 0.0641
# Epoch 6 | Batch 400/1084 | Loss: 0.0270
# Epoch 6 | Batch 410/1084 | Loss: 0.0211
# Epoch 6 | Batch 420/1084 | Loss: 0.0308
# Epoch 6 | Batch 430/1084 | Loss: 0.0652
# Epoch 6 | Batch 440/1084 | Loss: 0.0349
# Epoch 6 | Batch 450/1084 | Loss: 0.0245
# Epoch 6 | Batch 460/1084 | Loss: 0.0230
# Epoch 6 | Batch 470/1084 | Loss: 0.0237
# Epoch 6 | Batch 480/1084 | Loss: 0.0318
# Epoch 6 | Batch 490/1084 | Loss: 0.0412
# Epoch 6 | Batch 500/1084 | Loss: 0.0419
# Epoch 6 | Batch 510/1084 | Loss: 0.0348
# Epoch 6 | Batch 520/1084 | Loss: 0.0322
# Epoch 6 | Batch 530/1084 | Loss: 0.0298
# Epoch 6 | Batch 540/1084 | Loss: 0.0329
# Epoch 6 | Batch 550/1084 | Loss: 0.0212
# Epoch 6 | Batch 560/1084 | Loss: 0.0292
# Epoch 6 | Batch 570/1084 | Loss: 0.0628
# Epoch 6 | Batch 580/1084 | Loss: 0.0177
# Epoch 6 | Batch 590/1084 | Loss: 0.0197
# Epoch 6 | Batch 600/1084 | Loss: 0.0706
# Epoch 6 | Batch 610/1084 | Loss: 0.0290
# Epoch 6 | Batch 620/1084 | Loss: 0.0220
# Epoch 6 | Batch 630/1084 | Loss: 0.0248
# Epoch 6 | Batch 640/1084 | Loss: 0.0259
# Epoch 6 | Batch 650/1084 | Loss: 0.0378
# Epoch 6 | Batch 660/1084 | Loss: 0.0293
# Epoch 6 | Batch 670/1084 | Loss: 0.0321
# Epoch 6 | Batch 680/1084 | Loss: 0.0225
# Epoch 6 | Batch 690/1084 | Loss: 0.0149
# Epoch 6 | Batch 700/1084 | Loss: 0.0173
# Epoch 6 | Batch 710/1084 | Loss: 0.0451
# Epoch 6 | Batch 720/1084 | Loss: 0.0431
# Epoch 6 | Batch 730/1084 | Loss: 0.0274
# Epoch 6 | Batch 740/1084 | Loss: 0.0411
# Epoch 6 | Batch 750/1084 | Loss: 0.0542
# Epoch 6 | Batch 760/1084 | Loss: 0.0392
# Epoch 6 | Batch 770/1084 | Loss: 0.0440
# Epoch 6 | Batch 780/1084 | Loss: 0.0183
# Epoch 6 | Batch 790/1084 | Loss: 0.0631
# Epoch 6 | Batch 800/1084 | Loss: 0.0394
# Epoch 6 | Batch 810/1084 | Loss: 0.0253
# Epoch 6 | Batch 820/1084 | Loss: 0.0246
# Epoch 6 | Batch 830/1084 | Loss: 0.0198
# Epoch 6 | Batch 840/1084 | Loss: 0.0396
# Epoch 6 | Batch 850/1084 | Loss: 0.0386
# Epoch 6 | Batch 860/1084 | Loss: 0.0450
# Epoch 6 | Batch 870/1084 | Loss: 0.0225
# Epoch 6 | Batch 880/1084 | Loss: 0.0247
# Epoch 6 | Batch 890/1084 | Loss: 0.0196
# Epoch 6 | Batch 900/1084 | Loss: 0.0363
# Epoch 6 | Batch 910/1084 | Loss: 0.0184
# Epoch 6 | Batch 920/1084 | Loss: 0.0371
# Epoch 6 | Batch 930/1084 | Loss: 0.0221
# Epoch 6 | Batch 940/1084 | Loss: 0.0302
# Epoch 6 | Batch 950/1084 | Loss: 0.0406
# Epoch 6 | Batch 960/1084 | Loss: 0.0337
# Epoch 6 | Batch 970/1084 | Loss: 0.0447
# Epoch 6 | Batch 980/1084 | Loss: 0.0190
# Epoch 6 | Batch 990/1084 | Loss: 0.0296
# Epoch 6 | Batch 1000/1084 | Loss: 0.0613
# Epoch 6 | Batch 1010/1084 | Loss: 0.0167
# Epoch 6 | Batch 1020/1084 | Loss: 0.0499
# Epoch 6 | Batch 1030/1084 | Loss: 0.0376
# Epoch 6 | Batch 1040/1084 | Loss: 0.0218
# Epoch 6 | Batch 1050/1084 | Loss: 0.0791
# Epoch 6 | Batch 1060/1084 | Loss: 0.0296
# Epoch 6 | Batch 1070/1084 | Loss: 0.0313
# Epoch 6 | Batch 1080/1084 | Loss: 0.0174
# ✅ Epoch 6 complete | Avg Loss: 0.0361
# Epoch 7 | Batch 0/1084 | Loss: 0.0268
# Epoch 7 | Batch 10/1084 | Loss: 0.0185
# Epoch 7 | Batch 20/1084 | Loss: 0.0227
# Epoch 7 | Batch 30/1084 | Loss: 0.0409
# Epoch 7 | Batch 40/1084 | Loss: 0.0192
# Epoch 7 | Batch 50/1084 | Loss: 0.0504
# Epoch 7 | Batch 60/1084 | Loss: 0.0236
# Epoch 7 | Batch 70/1084 | Loss: 0.0743
# Epoch 7 | Batch 80/1084 | Loss: 0.0190
# Epoch 7 | Batch 90/1084 | Loss: 0.0375
# Epoch 7 | Batch 100/1084 | Loss: 0.0652
# Epoch 7 | Batch 640/1084 | Loss: 0.0206
# Epoch 7 | Batch 650/1084 | Loss: 0.0257
# Epoch 7 | Batch 660/1084 | Loss: 0.0585
# Epoch 7 | Batch 670/1084 | Loss: 0.0424
# Epoch 7 | Batch 680/1084 | Loss: 0.0318
# Epoch 7 | Batch 690/1084 | Loss: 0.0344
# Epoch 7 | Batch 700/1084 | Loss: 0.0268
# Epoch 7 | Batch 710/1084 | Loss: 0.0322
# Epoch 7 | Batch 720/1084 | Loss: 0.0498
# Epoch 7 | Batch 730/1084 | Loss: 0.0302
# Epoch 7 | Batch 740/1084 | Loss: 0.0354
# Epoch 7 | Batch 750/1084 | Loss: 0.0210
# Epoch 7 | Batch 760/1084 | Loss: 0.0131
# Epoch 7 | Batch 770/1084 | Loss: 0.0141
# Epoch 7 | Batch 780/1084 | Loss: 0.0289
# Epoch 7 | Batch 790/1084 | Loss: 0.0496
# Epoch 7 | Batch 800/1084 | Loss: 0.0105
# Epoch 7 | Batch 810/1084 | Loss: 0.0297
# Epoch 7 | Batch 820/1084 | Loss: 0.0550
# Epoch 7 | Batch 830/1084 | Loss: 0.0282
# Epoch 7 | Batch 840/1084 | Loss: 0.0222
# Epoch 7 | Batch 850/1084 | Loss: 0.0395
# Epoch 7 | Batch 860/1084 | Loss: 0.0415
# Epoch 7 | Batch 870/1084 | Loss: 0.0722
# Epoch 7 | Batch 880/1084 | Loss: 0.0411
# Epoch 7 | Batch 890/1084 | Loss: 0.0275
# Epoch 7 | Batch 900/1084 | Loss: 0.0580
# Epoch 7 | Batch 910/1084 | Loss: 0.0431
# Epoch 7 | Batch 920/1084 | Loss: 0.0452
# Epoch 7 | Batch 930/1084 | Loss: 0.0508
# Epoch 7 | Batch 940/1084 | Loss: 0.0392
# Epoch 7 | Batch 950/1084 | Loss: 0.0217
# Epoch 7 | Batch 960/1084 | Loss: 0.0363
# Epoch 7 | Batch 970/1084 | Loss: 0.0154
# Epoch 7 | Batch 980/1084 | Loss: 0.0464
# Epoch 7 | Batch 990/1084 | Loss: 0.0224
# Epoch 7 | Batch 1000/1084 | Loss: 0.0194
# Epoch 7 | Batch 1010/1084 | Loss: 0.0164
# Epoch 7 | Batch 1020/1084 | Loss: 0.0429
# Epoch 7 | Batch 1030/1084 | Loss: 0.0373
# Epoch 7 | Batch 1040/1084 | Loss: 0.0154
# Epoch 7 | Batch 1050/1084 | Loss: 0.0234
# Epoch 7 | Batch 1060/1084 | Loss: 0.0246
# Epoch 7 | Batch 1070/1084 | Loss: 0.0084
# Epoch 7 | Batch 1080/1084 | Loss: 0.1003
# ✅ Epoch 7 complete | Avg Loss: 0.0328
# Epoch 8 | Batch 0/1084 | Loss: 0.0375
# Epoch 8 | Batch 10/1084 | Loss: 0.0112
# Epoch 8 | Batch 20/1084 | Loss: 0.0285
# Epoch 8 | Batch 30/1084 | Loss: 0.0474
# Epoch 8 | Batch 40/1084 | Loss: 0.0159
# Epoch 8 | Batch 50/1084 | Loss: 0.0491
# Epoch 8 | Batch 60/1084 | Loss: 0.0106
# Epoch 8 | Batch 70/1084 | Loss: 0.1471
# Epoch 10 | Batch 10/1084 | Loss: 0.0220
# Epoch 10 | Batch 20/1084 | Loss: 0.0425
# Epoch 10 | Batch 30/1084 | Loss: 0.0098
# Epoch 10 | Batch 40/1084 | Loss: 0.0249
# Epoch 10 | Batch 50/1084 | Loss: 0.0185
# Epoch 10 | Batch 60/1084 | Loss: 0.0205
# Epoch 10 | Batch 70/1084 | Loss: 0.0149
# Epoch 10 | Batch 80/1084 | Loss: 0.0184
# Epoch 10 | Batch 90/1084 | Loss: 0.0274
# Epoch 10 | Batch 100/1084 | Loss: 0.0168
# Epoch 10 | Batch 110/1084 | Loss: 0.0372
# Epoch 10 | Batch 120/1084 | Loss: 0.0191
# Epoch 10 | Batch 130/1084 | Loss: 0.0068
# Epoch 10 | Batch 140/1084 | Loss: 0.0182
# Epoch 10 | Batch 150/1084 | Loss: 0.0316
# Epoch 10 | Batch 160/1084 | Loss: 0.0274
# Epoch 10 | Batch 170/1084 | Loss: 0.0129
# Epoch 10 | Batch 180/1084 | Loss: 0.0104
# Epoch 10 | Batch 190/1084 | Loss: 0.0194
# Epoch 10 | Batch 200/1084 | Loss: 0.0142
# Epoch 10 | Batch 210/1084 | Loss: 0.0117
# Epoch 10 | Batch 220/1084 | Loss: 0.0119
# Epoch 10 | Batch 230/1084 | Loss: 0.0185
# Epoch 10 | Batch 240/1084 | Loss: 0.0130
# Epoch 10 | Batch 250/1084 | Loss: 0.0534
# Epoch 10 | Batch 260/1084 | Loss: 0.0280
# Epoch 10 | Batch 270/1084 | Loss: 0.0132
# Epoch 10 | Batch 280/1084 | Loss: 0.0053
# Epoch 10 | Batch 290/1084 | Loss: 0.0154
# Epoch 10 | Batch 300/1084 | Loss: 0.0494
# Epoch 10 | Batch 310/1084 | Loss: 0.0520
# Epoch 10 | Batch 320/1084 | Loss: 0.0236
# Epoch 10 | Batch 330/1084 | Loss: 0.0200
# Epoch 10 | Batch 340/1084 | Loss: 0.0234
# Epoch 10 | Batch 350/1084 | Loss: 0.0407
# Epoch 10 | Batch 360/1084 | Loss: 0.0241
# Epoch 10 | Batch 370/1084 | Loss: 0.0332
# Epoch 10 | Batch 380/1084 | Loss: 0.0103
# Epoch 10 | Batch 390/1084 | Loss: 0.0096
# Epoch 10 | Batch 400/1084 | Loss: 0.0087
# Epoch 10 | Batch 410/1084 | Loss: 0.0147
# Epoch 10 | Batch 420/1084 | Loss: 0.0082
# Epoch 10 | Batch 430/1084 | Loss: 0.0289
# Epoch 10 | Batch 440/1084 | Loss: 0.0107
# Epoch 10 | Batch 450/1084 | Loss: 0.0057
# Epoch 10 | Batch 460/1084 | Loss: 0.0161
# Epoch 10 | Batch 470/1084 | Loss: 0.0108
# Epoch 10 | Batch 480/1084 | Loss: 0.0111
# Epoch 10 | Batch 490/1084 | Loss: 0.0333
# Epoch 10 | Batch 500/1084 | Loss: 0.0172
# Epoch 10 | Batch 510/1084 | Loss: 0.0262
# Epoch 10 | Batch 520/1084 | Loss: 0.0232
# Epoch 10 | Batch 530/1084 | Loss: 0.0120
# Epoch 10 | Batch 540/1084 | Loss: 0.0586
# Epoch 10 | Batch 550/1084 | Loss: 0.0129
# Epoch 10 | Batch 560/1084 | Loss: 0.0292
# Epoch 10 | Batch 570/1084 | Loss: 0.0091
# Epoch 10 | Batch 580/1084 | Loss: 0.0036
# Epoch 10 | Batch 590/1084 | Loss: 0.0104
# Epoch 10 | Batch 600/1084 | Loss: 0.0060
# Epoch 10 | Batch 610/1084 | Loss: 0.0617
# Epoch 10 | Batch 620/1084 | Loss: 0.0181
# Epoch 10 | Batch 630/1084 | Loss: 0.0119
# Epoch 10 | Batch 640/1084 | Loss: 0.0196
# Epoch 10 | Batch 650/1084 | Loss: 0.0996
# Epoch 10 | Batch 660/1084 | Loss: 0.0380
# Epoch 10 | Batch 670/1084 | Loss: 0.0904
# Epoch 10 | Batch 680/1084 | Loss: 0.0472
# Epoch 10 | Batch 690/1084 | Loss: 0.0123
# Epoch 10 | Batch 700/1084 | Loss: 0.0076
# Epoch 10 | Batch 710/1084 | Loss: 0.0076
# Epoch 10 | Batch 720/1084 | Loss: 0.0112
# Epoch 10 | Batch 730/1084 | Loss: 0.0171
# Epoch 10 | Batch 740/1084 | Loss: 0.0511
# Epoch 10 | Batch 750/1084 | Loss: 0.0242
# Epoch 10 | Batch 760/1084 | Loss: 0.0247
# Epoch 10 | Batch 770/1084 | Loss: 0.0283
# Epoch 10 | Batch 780/1084 | Loss: 0.0413
# Epoch 10 | Batch 790/1084 | Loss: 0.0252
# Epoch 10 | Batch 800/1084 | Loss: 0.0216
# Epoch 10 | Batch 810/1084 | Loss: 0.0456
# Epoch 10 | Batch 820/1084 | Loss: 0.0287
# Epoch 10 | Batch 830/1084 | Loss: 0.0234
# Epoch 10 | Batch 840/1084 | Loss: 0.0116
# Epoch 10 | Batch 850/1084 | Loss: 0.0345
# Epoch 10 | Batch 860/1084 | Loss: 0.0094
# Epoch 10 | Batch 870/1084 | Loss: 0.0327
# Epoch 10 | Batch 880/1084 | Loss: 0.0213
# Epoch 10 | Batch 890/1084 | Loss: 0.0128
# Epoch 10 | Batch 900/1084 | Loss: 0.0937
# Epoch 10 | Batch 910/1084 | Loss: 0.0332
# Epoch 10 | Batch 920/1084 | Loss: 0.0148
# Epoch 10 | Batch 930/1084 | Loss: 0.0113
# Epoch 10 | Batch 940/1084 | Loss: 0.0219
# Epoch 10 | Batch 950/1084 | Loss: 0.0090
# Epoch 10 | Batch 960/1084 | Loss: 0.0086
# Epoch 10 | Batch 970/1084 | Loss: 0.0119
# Epoch 10 | Batch 980/1084 | Loss: 0.0262
# Epoch 10 | Batch 990/1084 | Loss: 0.0311
# Epoch 10 | Batch 1000/1084 | Loss: 0.0114
# Epoch 10 | Batch 1010/1084 | Loss: 0.0154
# Epoch 10 | Batch 1020/1084 | Loss: 0.0273
# Epoch 10 | Batch 1030/1084 | Loss: 0.0107
# Epoch 10 | Batch 1040/1084 | Loss: 0.0115
# Epoch 10 | Batch 1050/1084 | Loss: 0.0179
# Epoch 10 | Batch 1060/1084 | Loss: 0.0229
# Epoch 10 | Batch 1070/1084 | Loss: 0.0308
# Epoch 10 | Batch 1080/1084 | Loss: 0.0095
# ✅ Epoch 10 complete | Avg Loss: 0.0240

# %%
# Build FAISS index using validation data with bounding box crop and category mapping

def crop_and_embed(image_path, annos_folder, model):
    img = Image.open(image_path).convert("RGB")
    ann_path = os.path.join(annos_folder, os.path.basename(image_path).replace('.jpg', '.json'))
    if os.path.isfile(ann_path):
        with open(ann_path) as f:
            ann = json.load(f)
            if "bounding_box" in ann:
                x, y, w, h = ann["bounding_box"]
                img = img.crop((x, y, x + w, y + h))
    img = transform(img).unsqueeze(0).to(DEVICE)
    model.eval()
    with torch.no_grad():
        return model(img).cpu().numpy()

def build_faiss_index(image_folder, annos_folder, json_path, model):
    index = faiss.IndexFlatL2(512)
    image_paths = []
    labels = []
    with open(json_path) as f:
        data = json.load(f)

    for entry in data:
        file = f"{entry['gallery_image_id']:06d}.jpg"
        full_path = os.path.join(image_folder, file)
        ann_path = os.path.join(annos_folder, file.replace(".jpg", ".json"))
        if os.path.isfile(full_path) and os.path.isfile(ann_path):
            emb = crop_and_embed(full_path, annos_folder, model)
            index.add(emb)
            image_paths.append(full_path)

            try:
                with open(ann_path) as f_ann:
                    ann_data = json.load(f_ann)
                    categories = []
                    for key, item in ann_data.items():
                        if key.startswith("item") and "category_name" in item:
                            categories.append(item["category_name"])
                    if categories:
                        labels.append(", ".join(categories))
                    else:
                        labels.append("Unknown")
            except:
                labels.append("Unknown")
    return index, image_paths, labels

# %%
# Retrieve and show categories (with duplicate filtering)
def retrieve_similar(query_image_path, index, image_paths, labels, annos_folder, top_k=5):
    def crop_and_embed_for_query(img_path):
        img = Image.open(img_path).convert("RGB")
        ann_path = os.path.join(annos_folder, os.path.basename(img_path).replace(".jpg", ".json"))
        if os.path.isfile(ann_path):
            with open(ann_path) as f:
                ann = json.load(f)
                if "bounding_box" in ann:
                    x, y, w, h = ann["bounding_box"]
                    img = img.crop((x, y, x + w, y + h))
        img = transform(img).unsqueeze(0).to(DEVICE)
        with torch.no_grad():
            return model(img).cpu().numpy()

    query_emb = crop_and_embed_for_query(query_image_path)
    D, I = index.search(query_emb, top_k * 2)

    seen = set()
    filtered_results = []
    for i, d in zip(I[0], D[0]):
        fname = os.path.basename(image_paths[i])
        if fname not in seen:
            seen.add(fname)
            filtered_results.append((image_paths[i], d, labels[i]))
        if len(filtered_results) == top_k:
            break

    print(f"\n🧥 Query: {os.path.basename(query_image_path)}")
    print("Top matches:")
    for rank, (path, dist, cat) in enumerate(filtered_results):
        print(f"{rank+1}. {os.path.basename(path)} | Distance: {dist:.4f} | Category: {cat}")

    return [path for path, _, _ in filtered_results], [dist for _, dist, _ in filtered_results]

# %%
def visualize_results(query_path, result_paths):
    import matplotlib.pyplot as plt
    from PIL import Image

    plt.figure(figsize=(15, 3))
    query_img = Image.open(query_path).convert("RGB")
    plt.subplot(1, len(result_paths) + 1, 1)
    plt.imshow(query_img)
    plt.title("Query")
    plt.axis("off")

    for i, path in enumerate(result_paths):
        img = Image.open(path).convert("RGB")
        plt.subplot(1, len(result_paths) + 1, i + 2)
        plt.imshow(img)
        plt.title(f"Result {i+1}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
image_folder = "validation/validation/image"
annos_folder = "validation/validation/annos"
json_path = "val_annotations/json_for_validation/val_gallery.json"

index, image_paths, labels = build_faiss_index(image_folder, annos_folder, json_path, model)


query_path = image_paths[0]


result_paths, distances = retrieve_similar(query_path, index, image_paths, labels, annos_folder, top_k=5)


visualize_results(query_path, result_paths)
# Out:
# 🧥 Query: 010845.jpg
# Top matches:
# 1. 010845.jpg | Distance: 0.0000 | Category: sling dress, vest
# 2. 023432.jpg | Distance: 0.0027 | Category: short sleeve dress
# 3. 010851.jpg | Distance: 0.0040 | Category: vest, sling dress
# 4. 010849.jpg | Distance: 0.0044 | Category: vest, sling dress
# 5. 010850.jpg | Distance: 0.0048 | Category: sling dress, vest

# %%
image_folder = "validation/validation/image"
annos_folder = "validation/validation/annos"
json_path = "val_annotations/json_for_validation/val_gallery.json"

index, image_paths, labels = build_faiss_index(image_folder, annos_folder, json_path, model)


query_path = image_paths[400]


result_paths, distances = retrieve_similar(query_path, index, image_paths, labels, annos_folder, top_k=5)


visualize_results(query_path, result_paths)
# Out:
# 🧥 Query: 011074.jpg
# Top matches:
# 1. 011074.jpg | Distance: 0.0000 | Category: vest, skirt
# 2. 011080.jpg | Distance: 0.0079 | Category: skirt, vest
# 3. 011081.jpg | Distance: 0.0139 | Category: skirt, vest
# 4. 011078.jpg | Distance: 0.0151 | Category: skirt, vest
# 5. 011079.jpg | Distance: 0.0175 | Category: skirt, vest

# %%
image_folder = "validation/validation/image"
annos_folder = "validation/validation/annos"
json_path = "val_annotations/json_for_validation/val_gallery.json"

index, image_paths, labels = build_faiss_index(image_folder, annos_folder, json_path, model)


query_path =  "TestingImage.jpg"


result_paths, distances = retrieve_similar(query_path, index, image_paths, labels, annos_folder, top_k=5)


visualize_results(query_path, result_paths)
# Out:
# 🧥 Query: TestingImage.jpg
# Top matches:
# 1. 025797.jpg | Distance: 0.0428 | Category: trousers, long sleeve top
# 2. 025802.jpg | Distance: 0.0439 | Category: long sleeve top
# 3. 025798.jpg | Distance: 0.0531 | Category: trousers, long sleeve top
# 4. 025810.jpg | Distance: 0.0822 | Category: trousers, long sleeve top
# 5. 011867.jpg | Distance: 0.0839 | Category: shorts, short sleeve top

# %%
image_folder = "validation/validation/image"
annos_folder = "validation/validation/annos"
json_path = "val_annotations/json_for_validation/val_gallery.json"

index, image_paths, labels = build_faiss_index(image_folder, annos_folder, json_path, model)


query_path =  "TestingImage3.jpg"


result_paths, distances = retrieve_similar(query_path, index, image_paths, labels, annos_folder, top_k=5)


visualize_results(query_path, result_paths)
# Out:
# 🧥 Query: TestingImage3.jpg
# Top matches:
# 1. 029367.jpg | Distance: 0.0981 | Category: trousers, long sleeve outwear
# 2. 020693.jpg | Distance: 0.1033 | Category: trousers, long sleeve outwear, long sleeve outwear, trousers
# 3. 021190.jpg | Distance: 0.1049 | Category: trousers, long sleeve top
# 4. 021197.jpg | Distance: 0.1237 | Category: trousers, long sleeve top
